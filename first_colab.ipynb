# %% [markdown]
# <a href="https://colab.research.google.com/github/myoungjinahn/machine_running_practice/blob/main/first_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###실습내용
#
# - 실습1:Google의 Colab으로 첫번째 파일 생성
# - 실습2:Git레포지토리 생성
# - 실습3:Colab 제공 기능으로 github에 업로드하기

# %% [markdown]
# ## hello world 출력하기
#
# = `print`함수 사용
#
# ```python
#
# a=1
#
# b="프린트"
# print(가)
# print(나)
# print(다)

# %%
print('hello world!')
# Out:
# hello world!

# %%
print('hello world')

print(1234)
print("1234")
# Out:
# hello world
# 1234
# 1234

# %% [markdown]
# ## 2. Tensorflow 불러오기

# %%
import tensorflow as tf

# %%
tf.__version__

#버전은 함수가 아니라 속성값이다
# Out:
# '2.19.0'

# %%
# !pwd
# Out:
# /content
